# %% [markdown]
# # W03-3 : 資料庫應用1
#
# - 講師有預先架設MySQL資料庫供大家練習，先以此資料庫進行學習

# %% [markdown]
# ### MySQL 操作

# %%
# add "+pymysql" in url for mysql module

mysql_db_url = 'mysql+pymysql://username:password@your-db-url:port/dbname'

# %%
# 先裝 mysql的connection driver
# pip install PyMySQL

from sqlalchemy import create_engine

my_db = create_engine(mysql_db_url)

# %% [markdown]
# - Create

# %%
# check and create table
resultProxy = my_db.execute("CREATE TABLE IF NOT EXISTS test_table(uuid text NOT NULL, time text NOT NULL, data text)")
resultProxy.__dict__
# Out:
# {'context': <sqlalchemy.dialects.mysql.mysqldb.MySQLExecutionContext_mysqldb at 0x20efc456c88>,
#  'dialect': <sqlalchemy.dialects.mysql.pymysql.MySQLDialect_pymysql at 0x20efc4560f0>,
#  'cursor': None,
#  '_saved_cursor': <pymysql.cursors.Cursor at 0x20efc456a90>,
#  'connection': <sqlalchemy.engine.base.Connection at 0x20efc4565f8>,
#  '_echo': False,
#  'rowcount': 0,
#  '_soft_closed': True}

# %% [markdown]
# - Insert

# %%
import time

my_time = time.strftime("%Y-%m-%d %H:%M:%S")
uuid = 'ming'
data = {"H": 70, "T": 32}
data = json.dumps(data)
resultProxy=my_db.execute("insert into test_table (uuid, time, data) values('%s', '%s', '%s')" %(uuid, my_time, data))

# %%
resultProxy.__dict__
# Out:
# {'context': <sqlalchemy.dialects.mysql.mysqldb.MySQLExecutionContext_mysqldb at 0x20efc496358>,
#  'dialect': <sqlalchemy.dialects.mysql.pymysql.MySQLDialect_pymysql at 0x20efc4560f0>,
#  'cursor': None,
#  '_saved_cursor': <pymysql.cursors.Cursor at 0x20efc4c01d0>,
#  'connection': <sqlalchemy.engine.base.Connection at 0x20efc4968d0>,
#  '_echo': False,
#  'rowcount': 1,
#  '_soft_closed': True}

# %% [markdown]
# - Select

# %%
# select
resultProxy=my_db.execute("select * from test_table")
data = resultProxy.fetchall()
print('-- data --')
print(data)
# Out:
# -- data --
# [('malo', '2021-09-20 22:27:08', '{"H": 80, "T": 30}'), ('jacky', '2021-09-20 22:28:00', '{"H": 80, "T": 30}'), ('malo', '2021-09-20 22:28:13', '{"H": 70, "T": 32}'), ('ming', '2021-09-20 22:32:37', '{"H": 70, "T": 32}')]

# %% [markdown]
# - Select: 有條件的

# %%
# select
resultProxy=my_db.execute("select * from test_table where uuid='jacky'")
data = resultProxy.fetchall()
print('-- data --')
print(data)
# Out:
# -- data --
# [('jacky', '2021-09-20 22:28:00', '{"H": 80, "T": 30}')]

# %% [markdown]
# - Delete

# %%
# select
resultProxy=my_db.execute("delete from test_table where uuid='ming'")

# %%
resultProxy.__dict__
# Out:
# {'context': <sqlalchemy.dialects.mysql.mysqldb.MySQLExecutionContext_mysqldb at 0x20efc496e10>,
#  'dialect': <sqlalchemy.dialects.mysql.pymysql.MySQLDialect_pymysql at 0x20efc4560f0>,
#  'cursor': None,
#  '_saved_cursor': <pymysql.cursors.Cursor at 0x20efc496eb8>,
#  'connection': <sqlalchemy.engine.base.Connection at 0x20efc496e48>,
#  '_echo': False,
#  'rowcount': 1,
#  '_soft_closed': True}

# %% [markdown]
# ## 練習題：把高雄空氣品質資料寫入資料庫中

# %% [markdown]
# - 提示：空氣品質資料來源

# %%
import requests
import sqlite3
import time
import json

#url = 'https://data.epa.gov.tw/api/v1/aqx_p_432?format=json&limit=5&api_key=9be7b239-557b-4c10-9775-78cadfc555e9'
url = 'https://data.epa.gov.tw/api/v1/aqx_p_432?format=json&api_key=9be7b239-557b-4c10-9775-78cadfc555e9'
r = requests.get(url)
print(r)
data = r.json()
# Out:
# <Response [200]>

# %%
# 舊的資料連結，今年變慢很多…先不再採用
import requests
import sqlite3
import time
import json

url = 'http://opendata.epa.gov.tw/ws/Data/AQI/?$format=json'
r = requests.get(url)
data = r.json()

# %%
data
# Out:
# {'sort': 'ImportDate desc',
#  'include_total': True,
#  'resource_id': '8ff027dc-2da2-42e8-85de-78ac3faf470e',
#  'fields': [{'info': {'notes': '', 'label': '測站名稱'},
#    'type': 'text',
#    'id': 'SiteName'},
#   {'info': {'notes': '', 'label': '縣市'}, 'type': 'text', 'id': 'County'},
#   {'info': {'notes': '', 'label': '空氣品質指標'}, 'type': 'text', 'id': 'AQI'},
#   {'info': {'notes': '', 'label': '空氣污染指標物'},
#    'type': 'text',
#    'id': 'Pollutant'},
#   {'info': {'notes': '', 'label': '狀態'}, 'type': 'text', 'id': 'Status'},
#   {'info': {'notes': '', 'label': '二氧化硫(ppb)'}, 'type': 'text', 'id': 'SO2'},
#   {'info': {'notes': '', 'label': '一氧化碳(ppm)'}, 'type': 'text', 'id': 'CO'},
#   {'info': {'notes': '', 'label': '一氧化碳8小時移動平均(ppm)'},
#    'type': 'text',
#    'id': 'CO_8hr'},
#   {'info': {'notes': '', 'label': '臭氧(ppb)'}, 'type': 'text', 'id': 'O3'},
#   {'info': {'notes': '', 'label': '臭氧8小時移動平均(ppb)'},
#    'type': 'text',
#    'id': 'O3_8hr'},
#   {'info': {'notes': '', 'label': '懸浮微粒(μg/m3)'},
#    'type': 'text',
#    'id': 'PM10'},
#   {'info': {'notes': '', 'label': '細懸浮微粒(μg/m3)'},
#    'type': 'text',
#    'id': 'PM2.5'},
#   {'info': {'notes': '', 'label': '二氧化氮(ppb)'}, 'type': 'text', 'id': 'NO2'},
#   {'info': {'notes': '', 'label': '氮氧化物(ppb)'}, 'type': 'text', 'id': 'NOx'},
#   {'info': {'notes': '', 'label': '一氧化氮(ppb)'}, 'type': 'text', 'id': 'NO'},
#   {'info': {'notes': '', 'label': '風速(m/sec)'},
#    'type': 'text',
#    'id': 'WindSpeed'},
#   {'info': {'notes': '', 'label': '風向(degrees)'},
#    'type': 'text',
#    'id': 'WindDirec'},
#   {'info': {'notes': '', 'label': '資料建置日期'},
#    'type': 'text',
#    'id': 'PublishTime'},
#   {'info': {'notes': '', 'label': '細懸浮微粒移動平均值(μg/m3)'},
#    'type': 'text',
#    'id': 'PM2.5_AVG'},
#   {'info': {'notes': '', 'label': '懸浮微粒移動平均值(μg/m3)'},
#    'type': 'text',
#    'id': 'PM10_AVG'},
#   {'info': {'notes': '', 'label': '二氧化硫移動平均值(ppb)'},
#    'type': 'text',
#    'id': 'SO2_AVG'},
#   {'info': {'notes': '', 'label': '經度'}, 'type': 'text', 'id': 'Longitude'},
#   {'info': {'notes': '', 'label': '緯度'}, 'type': 'text', 'id': 'Latitude'},
#   {'info': {'notes': '', 'label': '測站編號'}, 'type': 'text', 'id': 'SiteId'}],
#  '__extras': {'api_key': '9be7b239-557b-4c10-9775-78cadfc555e9'},
#  'records_format': 'objects',
#  'records': [{'SiteName': '基隆',
#    'County': '基隆市',
#    'AQI': '62',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.2',
#    'CO': '0.27',
#    'CO_8hr': '0.3',
#    'O3': '74.7',
#    'O3_8hr': '40',
#    'PM10': '35',
#    'PM2.5': '21',
#    'NO2': '4.7',
#    'NOx': '5.9',
#    'NO': '1.1',
#    'WindSpeed': '1.1',
#    'WindDirec': '46',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '30',
#    'SO2_AVG': '0',
#    'Longitude': '121.760056',
#    'Latitude': '25.129167',
#    'SiteId': '1',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '汐止',
#    'County': '新北市',
#    'AQI': '59',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.2',
#    'CO': '0.34',
#    'CO_8hr': '0.3',
#    'O3': '87.9',
#    'O3_8hr': '38',
#    'PM10': '34',
#    'PM2.5': '17',
#    'NO2': '10.4',
#    'NOx': '10.9',
#    'NO': '0.5',
#    'WindSpeed': '1.5',
#    'WindDirec': '41',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '30',
#    'SO2_AVG': '1',
#    'Longitude': '121.6423',
#    'Latitude': '25.067131',
#    'SiteId': '2',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '萬里',
#    'County': '新北市',
#    'AQI': '56',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.6',
#    'CO': '0.27',
#    'CO_8hr': '0.2',
#    'O3': '76.2',
#    'O3_8hr': '42',
#    'PM10': '36',
#    'PM2.5': '19',
#    'NO2': '3.5',
#    'NOx': '4.4',
#    'NO': '0.8',
#    'WindSpeed': '3',
#    'WindDirec': '49',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '33',
#    'SO2_AVG': '0',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'SiteId': '3',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '新店',
#    'County': '新北市',
#    'AQI': '60',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.9',
#    'CO': '0.25',
#    'CO_8hr': '0.3',
#    'O3': '71.9',
#    'O3_8hr': '36',
#    'PM10': '35',
#    'PM2.5': '15',
#    'NO2': '5.7',
#    'NOx': '6.5',
#    'NO': '0.7',
#    'WindSpeed': '1.6',
#    'WindDirec': '332',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '34',
#    'SO2_AVG': '0',
#    'Longitude': '121.537778',
#    'Latitude': '24.977222',
#    'SiteId': '4',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '土城',
#    'County': '新北市',
#    'AQI': '60',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.2',
#    'CO': '0.27',
#    'CO_8hr': '0.3',
#    'O3': '73.3',
#    'O3_8hr': '36',
#    'PM10': '26',
#    'PM2.5': '15',
#    'NO2': '5.7',
#    'NOx': '6.7',
#    'NO': '1',
#    'WindSpeed': '2.6',
#    'WindDirec': '290',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '35',
#    'SO2_AVG': '1',
#    'Longitude': '121.451861',
#    'Latitude': '24.982528',
#    'SiteId': '5',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '板橋',
#    'County': '新北市',
#    'AQI': '62',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.7',
#    'CO': '0.28',
#    'CO_8hr': '0.3',
#    'O3': '75.5',
#    'O3_8hr': '36',
#    'PM10': '27',
#    'PM2.5': '18',
#    'NO2': '5.6',
#    'NOx': '6.3',
#    'NO': '0.7',
#    'WindSpeed': '3',
#    'WindDirec': '321',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'SiteId': '6',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '新莊',
#    'County': '新北市',
#    'AQI': '57',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.25',
#    'CO_8hr': '0.3',
#    'O3': '73.2',
#    'O3_8hr': '37',
#    'PM10': '30',
#    'PM2.5': '16',
#    'NO2': '5.9',
#    'NOx': '6.3',
#    'NO': '0.4',
#    'WindSpeed': '1.5',
#    'WindDirec': '5',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '32',
#    'SO2_AVG': '2',
#    'Longitude': '121.4325',
#    'Latitude': '25.037972',
#    'SiteId': '7',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '菜寮',
#    'County': '新北市',
#    'AQI': '61',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.6',
#    'CO': '0.24',
#    'CO_8hr': '0.3',
#    'O3': '70.1',
#    'O3_8hr': '35',
#    'PM10': '24',
#    'PM2.5': '21',
#    'NO2': '6.4',
#    'NOx': '7.2',
#    'NO': '0.8',
#    'WindSpeed': '2.7',
#    'WindDirec': '5',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '27',
#    'SO2_AVG': '1',
#    'Longitude': '121.481028',
#    'Latitude': '25.06895',
#    'SiteId': '8',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '林口',
#    'County': '新北市',
#    'AQI': '56',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.8',
#    'CO': '0.18',
#    'CO_8hr': '0.2',
#    'O3': '60.7',
#    'O3_8hr': '40',
#    'PM10': '24',
#    'PM2.5': '15',
#    'NO2': '4.1',
#    'NOx': '4.4',
#    'NO': '0.3',
#    'WindSpeed': '2.7',
#    'WindDirec': '309',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '25',
#    'SO2_AVG': '2',
#    'Longitude': '121.376869',
#    'Latitude': '25.077197',
#    'SiteId': '9',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '淡水',
#    'County': '新北市',
#    'AQI': '42',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1',
#    'CO': '0.13',
#    'CO_8hr': '0.1',
#    'O3': '50.4',
#    'O3_8hr': '30',
#    'PM10': '23',
#    'PM2.5': '11',
#    'NO2': '2.6',
#    'NOx': '3.2',
#    'NO': '0.6',
#    'WindSpeed': '1',
#    'WindDirec': '330',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '12',
#    'PM10_AVG': '23',
#    'SO2_AVG': '1',
#    'Longitude': '121.449239',
#    'Latitude': '25.1645',
#    'SiteId': '10',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '士林',
#    'County': '臺北市',
#    'AQI': '59',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.19',
#    'CO_8hr': '0.3',
#    'O3': '69.9',
#    'O3_8hr': '39',
#    'PM10': '37',
#    'PM2.5': '15',
#    'NO2': '7',
#    'NOx': '8.2',
#    'NO': '1.2',
#    'WindSpeed': '3.2',
#    'WindDirec': '306',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '37',
#    'SO2_AVG': '0',
#    'Longitude': '121.515389',
#    'Latitude': '25.105417',
#    'SiteId': '11',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '中山',
#    'County': '臺北市',
#    'AQI': '61',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.7',
#    'CO': '0.38',
#    'CO_8hr': '0.4',
#    'O3': '70',
#    'O3_8hr': '35',
#    'PM10': '27',
#    'PM2.5': '19',
#    'NO2': '10.8',
#    'NOx': '12.8',
#    'NO': '2',
#    'WindSpeed': '1.9',
#    'WindDirec': '352',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '32',
#    'SO2_AVG': '1',
#    'Longitude': '121.526528',
#    'Latitude': '25.062361',
#    'SiteId': '12',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '萬華',
#    'County': '臺北市',
#    'AQI': '63',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.3',
#    'CO': '0.34',
#    'CO_8hr': '0.4',
#    'O3': '71.4',
#    'O3_8hr': '34',
#    'PM10': '24',
#    'PM2.5': '20',
#    'NO2': '9.6',
#    'NOx': '10.3',
#    'NO': '0.6',
#    'WindSpeed': '2.9',
#    'WindDirec': '27',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '121.507972',
#    'Latitude': '25.046503',
#    'SiteId': '13',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '古亭',
#    'County': '臺北市',
#    'AQI': '64',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.4',
#    'CO': '0.28',
#    'CO_8hr': '0.3',
#    'O3': '75.8',
#    'O3_8hr': '37',
#    'PM10': '26',
#    'PM2.5': '16',
#    'NO2': '8.5',
#    'NOx': '10.1',
#    'NO': '1.6',
#    'WindSpeed': '1.1',
#    'WindDirec': '312',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '38',
#    'SO2_AVG': '0',
#    'Longitude': '121.529556',
#    'Latitude': '25.020608',
#    'SiteId': '14',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '松山',
#    'County': '臺北市',
#    'AQI': '59',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.31',
#    'CO_8hr': '0.3',
#    'O3': '80.2',
#    'O3_8hr': '36',
#    'PM10': '33',
#    'PM2.5': '25',
#    'NO2': '10.8',
#    'NOx': '12.7',
#    'NO': '1.9',
#    'WindSpeed': '1.9',
#    'WindDirec': '314',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '121.578611',
#    'Latitude': '25.05',
#    'SiteId': '15',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '大同',
#    'County': '臺北市',
#    'AQI': '69',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.8',
#    'CO': '0.66',
#    'CO_8hr': '1.4',
#    'O3': '56.7',
#    'O3_8hr': '22',
#    'PM10': '43',
#    'PM2.5': '26',
#    'NO2': '17.4',
#    'NOx': '20.3',
#    'NO': '2.8',
#    'WindSpeed': '-',
#    'WindDirec': '-',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '38',
#    'SO2_AVG': '2',
#    'Longitude': '121.513311',
#    'Latitude': '25.0632',
#    'SiteId': '16',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '桃園',
#    'County': '桃園市',
#    'AQI': '63',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.9',
#    'CO': '0.22',
#    'CO_8hr': '0.2',
#    'O3': '53.7',
#    'O3_8hr': '35',
#    'PM10': '28',
#    'PM2.5': '20',
#    'NO2': '12.9',
#    'NOx': '16.5',
#    'NO': '3.5',
#    'WindSpeed': '2.1',
#    'WindDirec': '292',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '30',
#    'SO2_AVG': '1',
#    'Longitude': '121.30872222',
#    'Latitude': '24.98677778',
#    'SiteId': '17',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '大園',
#    'County': '桃園市',
#    'AQI': '42',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.7',
#    'CO': '0.18',
#    'CO_8hr': '0.1',
#    'O3': '46.5',
#    'O3_8hr': '34',
#    'PM10': '21',
#    'PM2.5': '8',
#    'NO2': '3.7',
#    'NOx': '4.7',
#    'NO': '0.9',
#    'WindSpeed': '3.5',
#    'WindDirec': '237',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '12',
#    'PM10_AVG': '23',
#    'SO2_AVG': '1',
#    'Longitude': '121.201811',
#    'Latitude': '25.060344',
#    'SiteId': '18',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '觀音',
#    'County': '桃園市',
#    'AQI': '39',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.8',
#    'CO': '0.23',
#    'CO_8hr': '0.1',
#    'O3': '54.6',
#    'O3_8hr': '35',
#    'PM10': '21',
#    'PM2.5': '14',
#    'NO2': '4.4',
#    'NOx': '5.2',
#    'NO': '0.8',
#    'WindSpeed': '4.5',
#    'WindDirec': '259',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '12',
#    'PM10_AVG': '19',
#    'SO2_AVG': '1',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'SiteId': '19',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '平鎮',
#    'County': '桃園市',
#    'AQI': '63',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.8',
#    'CO': '0.19',
#    'CO_8hr': '0.2',
#    'O3': '54.2',
#    'O3_8hr': '35',
#    'PM10': '22',
#    'PM2.5': '16',
#    'NO2': '4.8',
#    'NOx': '5.5',
#    'NO': '0.7',
#    'WindSpeed': '2.6',
#    'WindDirec': '274',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '27',
#    'SO2_AVG': '1',
#    'Longitude': '121.203986',
#    'Latitude': '24.952786',
#    'SiteId': '20',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '龍潭',
#    'County': '桃園市',
#    'AQI': '63',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.26',
#    'CO_8hr': '0.3',
#    'O3': '63.7',
#    'O3_8hr': '36',
#    'PM10': '25',
#    'PM2.5': '15',
#    'NO2': '5.9',
#    'NOx': '7.1',
#    'NO': '1.2',
#    'WindSpeed': '2.8',
#    'WindDirec': '261',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '32',
#    'SO2_AVG': '1',
#    'Longitude': '121.21635',
#    'Latitude': '24.863869',
#    'SiteId': '21',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '湖口',
#    'County': '新竹縣',
#    'AQI': '59',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.17',
#    'CO_8hr': '0.2',
#    'O3': '57.6',
#    'O3_8hr': '32',
#    'PM10': '28',
#    'PM2.5': '17',
#    'NO2': '3.3',
#    'NOx': '3.7',
#    'NO': '0.4',
#    'WindSpeed': '3.9',
#    'WindDirec': '278',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '30',
#    'SO2_AVG': '1',
#    'Longitude': '121.038653',
#    'Latitude': '24.900142',
#    'SiteId': '22',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '竹東',
#    'County': '新竹縣',
#    'AQI': '69',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.22',
#    'CO_8hr': '0.2',
#    'O3': '59.2',
#    'O3_8hr': '34',
#    'PM10': '23',
#    'PM2.5': '16',
#    'NO2': '3.4',
#    'NOx': '4.2',
#    'NO': '0.7',
#    'WindSpeed': '2.1',
#    'WindDirec': '247',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '33',
#    'SO2_AVG': '0',
#    'Longitude': '121.088903',
#    'Latitude': '24.740644',
#    'SiteId': '23',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '新竹',
#    'County': '新竹市',
#    'AQI': '64',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.4',
#    'CO': '0.26',
#    'CO_8hr': '0.3',
#    'O3': '56.1',
#    'O3_8hr': '30',
#    'PM10': '31',
#    'PM2.5': '17',
#    'NO2': '7',
#    'NOx': '8.1',
#    'NO': '1.1',
#    'WindSpeed': '2.4',
#    'WindDirec': '301',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '28',
#    'SO2_AVG': '1',
#    'Longitude': '120.972075',
#    'Latitude': '24.805619',
#    'SiteId': '24',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '頭份',
#    'County': '苗栗縣',
#    'AQI': '60',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.3',
#    'CO': '0.23',
#    'CO_8hr': '0.2',
#    'O3': '62.3',
#    'O3_8hr': '34',
#    'PM10': '31',
#    'PM2.5': '15',
#    'NO2': '4.7',
#    'NOx': '6.5',
#    'NO': '1.7',
#    'WindSpeed': '2.8',
#    'WindDirec': '287',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '30',
#    'SO2_AVG': '2',
#    'Longitude': '120.898572',
#    'Latitude': '24.696969',
#    'SiteId': '25',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '苗栗',
#    'County': '苗栗縣',
#    'AQI': '66',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.8',
#    'CO': '0.16',
#    'CO_8hr': '0.2',
#    'O3': '55',
#    'O3_8hr': '38',
#    'PM10': '19',
#    'PM2.5': '14',
#    'NO2': '5.6',
#    'NOx': '6.8',
#    'NO': '1.2',
#    'WindSpeed': '2.5',
#    'WindDirec': '281',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '21',
#    'PM10_AVG': '30',
#    'SO2_AVG': '2',
#    'Longitude': '120.8202',
#    'Latitude': '24.565269',
#    'SiteId': '26',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '三義',
#    'County': '苗栗縣',
#    'AQI': '62',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.7',
#    'CO': '0.25',
#    'CO_8hr': '0.2',
#    'O3': '66.5',
#    'O3_8hr': '44',
#    'PM10': '30',
#    'PM2.5': '21',
#    'NO2': '4.6',
#    'NOx': '6.1',
#    'NO': '1.5',
#    'WindSpeed': '2',
#    'WindDirec': '298',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'SiteId': '27',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '豐原',
#    'County': '臺中市',
#    'AQI': '59',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2',
#    'CO': '0.28',
#    'CO_8hr': '0.3',
#    'O3': '81.3',
#    'O3_8hr': '42',
#    'PM10': '36',
#    'PM2.5': '22',
#    'NO2': '6.8',
#    'NOx': '8',
#    'NO': '1.2',
#    'WindSpeed': '2.8',
#    'WindDirec': '288',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '29',
#    'SO2_AVG': '1',
#    'Longitude': '120.741711',
#    'Latitude': '24.256586',
#    'SiteId': '28',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '沙鹿',
#    'County': '臺中市',
#    'AQI': '79',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '5.1',
#    'CO': '0.52',
#    'CO_8hr': '0.3',
#    'O3': '48',
#    'O3_8hr': '36',
#    'PM10': '47',
#    'PM2.5': '21',
#    'NO2': '14.2',
#    'NOx': '18.2',
#    'NO': '3.9',
#    'WindSpeed': '2.9',
#    'WindDirec': '315',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '26',
#    'PM10_AVG': '47',
#    'SO2_AVG': '2',
#    'Longitude': '120.568794',
#    'Latitude': '24.225628',
#    'SiteId': '29',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '大里',
#    'County': '臺中市',
#    'AQI': '61',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.9',
#    'CO': '0.2',
#    'CO_8hr': '0.3',
#    'O3': '67.8',
#    'O3_8hr': '37',
#    'PM10': '29',
#    'PM2.5': '20',
#    'NO2': '5',
#    'NOx': '6.3',
#    'NO': '1.3',
#    'WindSpeed': '2.8',
#    'WindDirec': '250',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '33',
#    'SO2_AVG': '2',
#    'Longitude': '120.67844444',
#    'Latitude': '24.09961111',
#    'SiteId': '30',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '忠明',
#    'County': '臺中市',
#    'AQI': '55',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.28',
#    'CO_8hr': '0.2',
#    'O3': '71',
#    'O3_8hr': '44',
#    'PM10': '31',
#    'PM2.5': '18',
#    'NO2': '11.2',
#    'NOx': '12',
#    'NO': '0.8',
#    'WindSpeed': '1.9',
#    'WindDirec': '301',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '29',
#    'SO2_AVG': '1',
#    'Longitude': '120.641092',
#    'Latitude': '24.151958',
#    'SiteId': '31',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '西屯',
#    'County': '臺中市',
#    'AQI': '64',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.3',
#    'CO': '0.21',
#    'CO_8hr': '0.2',
#    'O3': '64.5',
#    'O3_8hr': '38',
#    'PM10': '42',
#    'PM2.5': '20',
#    'NO2': '4.7',
#    'NOx': '5.7',
#    'NO': '1',
#    'WindSpeed': '2.6',
#    'WindDirec': '268',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '36',
#    'SO2_AVG': '2',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'SiteId': '32',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '彰化',
#    'County': '彰化縣',
#    'AQI': '71',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.3',
#    'CO': '0.11',
#    'CO_8hr': '0.1',
#    'O3': '62.5',
#    'O3_8hr': '40',
#    'PM10': '28',
#    'PM2.5': '18',
#    'NO2': '4.8',
#    'NOx': '5.3',
#    'NO': '0.5',
#    'WindSpeed': '2.4',
#    'WindDirec': '291',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '23',
#    'PM10_AVG': '41',
#    'SO2_AVG': '3',
#    'Longitude': '120.541519',
#    'Latitude': '24.066',
#    'SiteId': '33',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '線西',
#    'County': '彰化縣',
#    'AQI': '62',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.6',
#    'CO': '0.14',
#    'CO_8hr': '0.2',
#    'O3': '50.2',
#    'O3_8hr': '34',
#    'PM10': '14',
#    'PM2.5': '14',
#    'NO2': '2.1',
#    'NOx': '3.1',
#    'NO': '0.9',
#    'WindSpeed': '3.8',
#    'WindDirec': '296',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '50',
#    'SO2_AVG': '2',
#    'Longitude': '120.469061',
#    'Latitude': '24.131672',
#    'SiteId': '34',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '二林',
#    'County': '彰化縣',
#    'AQI': '69',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '3.4',
#    'CO': '0.15',
#    'CO_8hr': '0.2',
#    'O3': '47.2',
#    'O3_8hr': '30',
#    'PM10': '25',
#    'PM2.5': '14',
#    'NO2': '2.1',
#    'NOx': '3.4',
#    'NO': '1.2',
#    'WindSpeed': '1.9',
#    'WindDirec': '290',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '',
#    'SO2_AVG': '2',
#    'Longitude': '120.409653',
#    'Latitude': '23.925175',
#    'SiteId': '35',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '南投',
#    'County': '南投縣',
#    'AQI': '67',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.7',
#    'CO': '0.21',
#    'CO_8hr': '0.2',
#    'O3': '62.6',
#    'O3_8hr': '32',
#    'PM10': '33',
#    'PM2.5': '25',
#    'NO2': '4.9',
#    'NOx': '6.2',
#    'NO': '1.2',
#    'WindSpeed': '1.4',
#    'WindDirec': '41',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '33',
#    'SO2_AVG': '2',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'SiteId': '36',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '斗六',
#    'County': '雲林縣',
#    'AQI': '58',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.1',
#    'CO': '0.19',
#    'CO_8hr': '0.2',
#    'O3': '71.9',
#    'O3_8hr': '37',
#    'PM10': '29',
#    'PM2.5': '20',
#    'NO2': '3.9',
#    'NOx': '5.4',
#    'NO': '1.5',
#    'WindSpeed': '1.1',
#    'WindDirec': '253',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '27',
#    'SO2_AVG': '2',
#    'Longitude': '120.544994',
#    'Latitude': '23.711853',
#    'SiteId': '37',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '崙背',
#    'County': '雲林縣',
#    'AQI': '73',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.9',
#    'CO': '0.17',
#    'CO_8hr': '0.2',
#    'O3': '60.7',
#    'O3_8hr': '34',
#    'PM10': '25',
#    'PM2.5': '19',
#    'NO2': '8.2',
#    'NOx': '9.3',
#    'NO': '1.1',
#    'WindSpeed': '1.8',
#    'WindDirec': '300',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '24',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'SiteId': '38',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '新港',
#    'County': '嘉義縣',
#    'AQI': '59',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.7',
#    'CO': '0.17',
#    'CO_8hr': '0.2',
#    'O3': '60.4',
#    'O3_8hr': '34',
#    'PM10': '40',
#    'PM2.5': '22',
#    'NO2': '4.1',
#    'NOx': '5.4',
#    'NO': '1.3',
#    'WindSpeed': '2',
#    'WindDirec': '284',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '18',
#    'PM10_AVG': '32',
#    'SO2_AVG': '2',
#    'Longitude': '120.345531',
#    'Latitude': '23.554839',
#    'SiteId': '39',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '朴子',
#    'County': '嘉義縣',
#    'AQI': '51',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.15',
#    'CO_8hr': '0.2',
#    'O3': '42.1',
#    'O3_8hr': '32',
#    'PM10': '17',
#    'PM2.5': '10',
#    'NO2': '2.4',
#    'NOx': '4.3',
#    'NO': '1.9',
#    'WindSpeed': '2.7',
#    'WindDirec': '289',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '15',
#    'PM10_AVG': '30',
#    'SO2_AVG': '1',
#    'Longitude': '120.24781111',
#    'Latitude': '23.46712222',
#    'SiteId': '40',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '臺西',
#    'County': '雲林縣',
#    'AQI': '55',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.9',
#    'CO': '0.15',
#    'CO_8hr': '0.2',
#    'O3': '52.9',
#    'O3_8hr': '34',
#    'PM10': '17',
#    'PM2.5': '10',
#    'NO2': '5',
#    'NOx': '4.9',
#    'NO': '0',
#    'WindSpeed': '2.9',
#    'WindDirec': '299',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '120.19933333',
#    'Latitude': '23.702175',
#    'SiteId': '41',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '嘉義',
#    'County': '嘉義市',
#    'AQI': '51',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.8',
#    'CO': '0.19',
#    'CO_8hr': '0.2',
#    'O3': '56.6',
#    'O3_8hr': '31',
#    'PM10': '25',
#    'PM2.5': '17',
#    'NO2': '1.6',
#    'NOx': '3.1',
#    'NO': '1.4',
#    'WindSpeed': '1.4',
#    'WindDirec': '334',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '15',
#    'PM10_AVG': '24',
#    'SO2_AVG': '1',
#    'Longitude': '120.44083333',
#    'Latitude': '23.462778',
#    'SiteId': '42',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '新營',
#    'County': '臺南市',
#    'AQI': '54',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.7',
#    'CO': '0.2',
#    'CO_8hr': '0.2',
#    'O3': '60',
#    'O3_8hr': '38',
#    'PM10': '35',
#    'PM2.5': '18',
#    'NO2': '3.7',
#    'NOx': '4.1',
#    'NO': '0.4',
#    'WindSpeed': '1.3',
#    'WindDirec': '1',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '16',
#    'PM10_AVG': '29',
#    'SO2_AVG': '0',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'SiteId': '43',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '善化',
#    'County': '臺南市',
#    'AQI': '46',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.3',
#    'CO': '0.14',
#    'CO_8hr': '0.1',
#    'O3': '54.2',
#    'O3_8hr': '31',
#    'PM10': '29',
#    'PM2.5': '16',
#    'NO2': '2.7',
#    'NOx': '3.6',
#    'NO': '0.9',
#    'WindSpeed': '1.3',
#    'WindDirec': '296',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '14',
#    'PM10_AVG': '23',
#    'SO2_AVG': '0',
#    'Longitude': '120.297142',
#    'Latitude': '23.115097',
#    'SiteId': '44',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '安南',
#    'County': '臺南市',
#    'AQI': '40',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.9',
#    'CO': '0.17',
#    'CO_8hr': '0.2',
#    'O3': '44',
#    'O3_8hr': '31',
#    'PM10': '16',
#    'PM2.5': '5',
#    'NO2': '0.6',
#    'NOx': '0.4',
#    'NO': '0',
#    'WindSpeed': '3.7',
#    'WindDirec': '309',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '12',
#    'PM10_AVG': '24',
#    'SO2_AVG': '1',
#    'Longitude': '120.2175',
#    'Latitude': '23.048197',
#    'SiteId': '45',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '臺南',
#    'County': '臺南市',
#    'AQI': '54',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.9',
#    'CO': '0.18',
#    'CO_8hr': '0.2',
#    'O3': '47.2',
#    'O3_8hr': '38',
#    'PM10': '24',
#    'PM2.5': '12',
#    'NO2': '3.6',
#    'NOx': '4.1',
#    'NO': '0.5',
#    'WindSpeed': '3.8',
#    'WindDirec': '281',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '16',
#    'PM10_AVG': '27',
#    'SO2_AVG': '1',
#    'Longitude': '120.202617',
#    'Latitude': '22.984581',
#    'SiteId': '46',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '美濃',
#    'County': '高雄市',
#    'AQI': '45',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.1',
#    'CO': '0.18',
#    'CO_8hr': '0.2',
#    'O3': '46.9',
#    'O3_8hr': '31',
#    'PM10': '19',
#    'PM2.5': '12',
#    'NO2': '1.6',
#    'NOx': '2',
#    'NO': '0.3',
#    'WindSpeed': '1.2',
#    'WindDirec': '283',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '13',
#    'PM10_AVG': '23',
#    'SO2_AVG': '1',
#    'Longitude': '120.530542',
#    'Latitude': '22.883583',
#    'SiteId': '47',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '橋頭',
#    'County': '高雄市',
#    'AQI': '56',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.4',
#    'CO': '0.22',
#    'CO_8hr': '0.2',
#    'O3': '53.6',
#    'O3_8hr': '35',
#    'PM10': '30',
#    'PM2.5': '14',
#    'NO2': '3.8',
#    'NOx': '4.8',
#    'NO': '0.9',
#    'WindSpeed': '3.6',
#    'WindDirec': '284',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '33',
#    'SO2_AVG': '0',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'SiteId': '48',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '仁武',
#    'County': '高雄市',
#    'AQI': '60',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.6',
#    'CO': '0.19',
#    'CO_8hr': '0.2',
#    'O3': '55',
#    'O3_8hr': '41',
#    'PM10': '21',
#    'PM2.5': '12',
#    'NO2': '5.5',
#    'NOx': '6.8',
#    'NO': '1.2',
#    'WindSpeed': '2.4',
#    'WindDirec': '283',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '29',
#    'SO2_AVG': '2',
#    'Longitude': '120.332631',
#    'Latitude': '22.689056',
#    'SiteId': '49',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '鳳山',
#    'County': '高雄市',
#    'AQI': '72',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.9',
#    'CO': '0.49',
#    'CO_8hr': '0.4',
#    'O3': '64.2',
#    'O3_8hr': '38',
#    'PM10': '28',
#    'PM2.5': '21',
#    'NO2': '11.6',
#    'NOx': '13.8',
#    'NO': '2.2',
#    'WindSpeed': '1.1',
#    'WindDirec': '221',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '24',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'SiteId': '50',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '大寮',
#    'County': '高雄市',
#    'AQI': '77',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.25',
#    'CO_8hr': '0.2',
#    'O3': '73.6',
#    'O3_8hr': '35',
#    'PM10': '36',
#    'PM2.5': '20',
#    'NO2': '4.4',
#    'NOx': '5.2',
#    'NO': '0.7',
#    'WindSpeed': '1.6',
#    'WindDirec': '335',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '25',
#    'PM10_AVG': '39',
#    'SO2_AVG': '2',
#    'Longitude': '120.425311',
#    'Latitude': '22.56413611',
#    'SiteId': '51',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '林園',
#    'County': '高雄市',
#    'AQI': '79',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.5',
#    'CO': '0.21',
#    'CO_8hr': '0.2',
#    'O3': '62.1',
#    'O3_8hr': '45',
#    'PM10': '30',
#    'PM2.5': '17',
#    'NO2': '5.1',
#    'NOx': '6.2',
#    'NO': '1.1',
#    'WindSpeed': '2.4',
#    'WindDirec': '287',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '26',
#    'PM10_AVG': '42',
#    'SO2_AVG': '2',
#    'Longitude': '120.41175',
#    'Latitude': '22.4795',
#    'SiteId': '52',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '楠梓',
#    'County': '高雄市',
#    'AQI': '82',
#    'Pollutant': '懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.3',
#    'CO': '0.22',
#    'CO_8hr': '0.3',
#    'O3': '59.1',
#    'O3_8hr': '38',
#    'PM10': '31',
#    'PM2.5': '14',
#    'NO2': '2.8',
#    'NOx': '3.9',
#    'NO': '1',
#    'WindSpeed': '3.3',
#    'WindDirec': '289',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '82',
#    'SO2_AVG': '1',
#    'Longitude': '120.328289',
#    'Latitude': '22.733667',
#    'SiteId': '53',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '左營',
#    'County': '高雄市',
#    'AQI': '69',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.4',
#    'CO': '0.14',
#    'CO_8hr': '0.3',
#    'O3': '43.7',
#    'O3_8hr': '45',
#    'PM10': '23',
#    'PM2.5': '13',
#    'NO2': '2.3',
#    'NOx': '3.2',
#    'NO': '0.9',
#    'WindSpeed': '2.8',
#    'WindDirec': '298',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '41',
#    'SO2_AVG': '1',
#    'Longitude': '120.292917',
#    'Latitude': '22.674861',
#    'SiteId': '54',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '前金',
#    'County': '高雄市',
#    'AQI': '67',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.19',
#    'CO_8hr': '0.3',
#    'O3': '54.7',
#    'O3_8hr': '44',
#    'PM10': '19',
#    'PM2.5': '15',
#    'NO2': '3.6',
#    'NOx': '4.2',
#    'NO': '0.5',
#    'WindSpeed': '2.9',
#    'WindDirec': '337',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '21',
#    'PM10_AVG': '30',
#    'SO2_AVG': '1',
#    'Longitude': '120.288086',
#    'Latitude': '22.632567',
#    'SiteId': '56',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '前鎮',
#    'County': '高雄市',
#    'AQI': '62',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.6',
#    'CO': '0.21',
#    'CO_8hr': '0.4',
#    'O3': '52.7',
#    'O3_8hr': '42',
#    'PM10': '25',
#    'PM2.5': '11',
#    'NO2': '6',
#    'NOx': '7.3',
#    'NO': '1.2',
#    'WindSpeed': '1.6',
#    'WindDirec': '352',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '37',
#    'SO2_AVG': '2',
#    'Longitude': '120.307564',
#    'Latitude': '22.605386',
#    'SiteId': '57',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '小港',
#    'County': '高雄市',
#    'AQI': '79',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.6',
#    'CO': '0.21',
#    'CO_8hr': '0.3',
#    'O3': '61',
#    'O3_8hr': '43',
#    'PM10': '30',
#    'PM2.5': '21',
#    'NO2': '9.8',
#    'NOx': '11.4',
#    'NO': '1.5',
#    'WindSpeed': '3.5',
#    'WindDirec': '278',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '26',
#    'PM10_AVG': '40',
#    'SO2_AVG': '2',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'SiteId': '58',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '屏東',
#    'County': '屏東縣',
#    'AQI': '56',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.2',
#    'CO_8hr': '0.2',
#    'O3': '55.8',
#    'O3_8hr': '32',
#    'PM10': '22',
#    'PM2.5': '13',
#    'NO2': '3.5',
#    'NOx': '4.5',
#    'NO': '1',
#    'WindSpeed': '1.9',
#    'WindDirec': '317',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '120.488033',
#    'Latitude': '22.673081',
#    'SiteId': '59',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '潮州',
#    'County': '屏東縣',
#    'AQI': '57',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.2',
#    'CO': '0.23',
#    'CO_8hr': '0.2',
#    'O3': '62.7',
#    'O3_8hr': '39',
#    'PM10': '31',
#    'PM2.5': '14',
#    'NO2': '1.4',
#    'NOx': '1.8',
#    'NO': '0.4',
#    'WindSpeed': '0.9',
#    'WindDirec': '318',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '17',
#    'PM10_AVG': '28',
#    'SO2_AVG': '1',
#    'Longitude': '120.561175',
#    'Latitude': '22.523108',
#    'SiteId': '60',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '恆春',
#    'County': '屏東縣',
#    'AQI': '10',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.9',
#    'CO': '0.09',
#    'CO_8hr': '0',
#    'O3': '18.3',
#    'O3_8hr': '11',
#    'PM10': '4',
#    'PM2.5': '1',
#    'NO2': '0.9',
#    'NOx': '3',
#    'NO': '2',
#    'WindSpeed': '1.8',
#    'WindDirec': '239',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '0',
#    'PM10_AVG': '4',
#    'SO2_AVG': '0',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'SiteId': '61',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '臺東',
#    'County': '臺東縣',
#    'AQI': '12',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.6',
#    'CO': '0.13',
#    'CO_8hr': '0.1',
#    'O3': '17.5',
#    'O3_8hr': '11',
#    'PM10': '8',
#    'PM2.5': '2',
#    'NO2': '2.7',
#    'NOx': '5.6',
#    'NO': '2.8',
#    'WindSpeed': '2.1',
#    'WindDirec': '126',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '3',
#    'PM10_AVG': '9',
#    'SO2_AVG': '1',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'SiteId': '62',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '花蓮',
#    'County': '花蓮縣',
#    'AQI': '10',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0',
#    'CO': '0.09',
#    'CO_8hr': '0.1',
#    'O3': '19.7',
#    'O3_8hr': '11',
#    'PM10': '2',
#    'PM2.5': '0',
#    'NO2': '2.1',
#    'NOx': '3.2',
#    'NO': '1.1',
#    'WindSpeed': '3',
#    'WindDirec': '135',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '2',
#    'PM10_AVG': '7',
#    'SO2_AVG': '0',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'SiteId': '63',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '陽明',
#    'County': '臺北市',
#    'AQI': '41',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.7',
#    'CO': '0.16',
#    'CO_8hr': '0.1',
#    'O3': '43.5',
#    'O3_8hr': '42',
#    'PM10': '15',
#    'PM2.5': '12',
#    'NO2': '2.5',
#    'NOx': '3',
#    'NO': '0.5',
#    'WindSpeed': '3.2',
#    'WindDirec': '350',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '12',
#    'PM10_AVG': '19',
#    'SO2_AVG': '1',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'SiteId': '64',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '宜蘭',
#    'County': '宜蘭縣',
#    'AQI': '33',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '3.9',
#    'CO': '0.24',
#    'CO_8hr': '0.2',
#    'O3': '48.2',
#    'O3_8hr': '25',
#    'PM10': '26',
#    'PM2.5': '13',
#    'NO2': '4.5',
#    'NOx': '5.7',
#    'NO': '1.1',
#    'WindSpeed': '2.8',
#    'WindDirec': '120',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '10',
#    'PM10_AVG': '20',
#    'SO2_AVG': '1',
#    'Longitude': '121.746394',
#    'Latitude': '24.747917',
#    'SiteId': '65',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '冬山',
#    'County': '宜蘭縣',
#    'AQI': '22',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.6',
#    'CO': '0.27',
#    'CO_8hr': '0.2',
#    'O3': '38.8',
#    'O3_8hr': '22',
#    'PM10': '20',
#    'PM2.5': '2',
#    'NO2': '6',
#    'NOx': '8.4',
#    'NO': '2.3',
#    'WindSpeed': '2.6',
#    'WindDirec': '126',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '6',
#    'PM10_AVG': '20',
#    'SO2_AVG': '0',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'SiteId': '66',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '三重',
#    'County': '新北市',
#    'AQI': '65',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.7',
#    'CO': '0.49',
#    'CO_8hr': '0.9',
#    'O3': '51.2',
#    'O3_8hr': '24',
#    'PM10': '37',
#    'PM2.5': '21',
#    'NO2': '24',
#    'NOx': '35',
#    'NO': '11',
#    'WindSpeed': '-',
#    'WindDirec': '-',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '21',
#    'PM10_AVG': '34',
#    'SO2_AVG': '1',
#    'Longitude': '121.493806',
#    'Latitude': '25.072611',
#    'SiteId': '67',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '中壢',
#    'County': '桃園市',
#    'AQI': '62',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.4',
#    'CO': '0.41',
#    'CO_8hr': '0.7',
#    'O3': '41.7',
#    'O3_8hr': '25',
#    'PM10': '26',
#    'PM2.5': '15',
#    'NO2': '15.3',
#    'NOx': '23.2',
#    'NO': '7.8',
#    'WindSpeed': '1.2',
#    'WindDirec': '26',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '121.221667',
#    'Latitude': '24.953278',
#    'SiteId': '68',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '竹山',
#    'County': '南投縣',
#    'AQI': '61',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.3',
#    'CO': '0.12',
#    'CO_8hr': '0.1',
#    'O3': '58',
#    'O3_8hr': '32',
#    'PM10': '30',
#    'PM2.5': '16',
#    'NO2': '4.2',
#    'NOx': '5.5',
#    'NO': '1.3',
#    'WindSpeed': '2.2',
#    'WindDirec': '258',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '29',
#    'SO2_AVG': '1',
#    'Longitude': '120.677306',
#    'Latitude': '23.756389',
#    'SiteId': '69',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '永和',
#    'County': '新北市',
#    'AQI': '66',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.5',
#    'CO': '0.49',
#    'CO_8hr': '0.5',
#    'O3': '',
#    'O3_8hr': '24',
#    'PM10': '',
#    'PM2.5': '21',
#    'NO2': '14.6',
#    'NOx': '17.6',
#    'NO': '2.9',
#    'WindSpeed': '1.8',
#    'WindDirec': '268',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '21',
#    'PM10_AVG': '33',
#    'SO2_AVG': '0',
#    'Longitude': '121.516306',
#    'Latitude': '25.017',
#    'SiteId': '70',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '復興',
#    'County': '高雄市',
#    'AQI': '77',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '',
#    'CO': '0.28',
#    'CO_8hr': '0.5',
#    'O3': '54.6',
#    'O3_8hr': '38',
#    'PM10': '24',
#    'PM2.5': '12',
#    'NO2': '5.8',
#    'NOx': '6.5',
#    'NO': '0.7',
#    'WindSpeed': '0.7',
#    'WindDirec': '210',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '25',
#    'PM10_AVG': '50',
#    'SO2_AVG': '',
#    'Longitude': '120.312017',
#    'Latitude': '22.608711',
#    'SiteId': '71',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '埔里',
#    'County': '南投縣',
#    'AQI': '69',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.22',
#    'CO_8hr': '0.3',
#    'O3': '46.9',
#    'O3_8hr': '28',
#    'PM10': '25',
#    'PM2.5': '19',
#    'NO2': '2',
#    'NOx': '3.2',
#    'NO': '1.2',
#    'WindSpeed': '2.4',
#    'WindDirec': '292',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '22',
#    'PM10_AVG': '31',
#    'SO2_AVG': '1',
#    'Longitude': '120.967903',
#    'Latitude': '23.968842',
#    'SiteId': '72',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '馬祖',
#    'County': '連江縣',
#    'AQI': '46',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.2',
#    'CO': '0.19',
#    'CO_8hr': '0.1',
#    'O3': '72.8',
#    'O3_8hr': '46',
#    'PM10': '33',
#    'PM2.5': '21',
#    'NO2': '4',
#    'NOx': '5.4',
#    'NO': '1.3',
#    'WindSpeed': '4.1',
#    'WindDirec': '176',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '14',
#    'PM10_AVG': '23',
#    'SO2_AVG': '0',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'SiteId': '75',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '金門',
#    'County': '金門縣',
#    'AQI': '50',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.9',
#    'CO': '0.11',
#    'CO_8hr': '0.1',
#    'O3': '30.2',
#    'O3_8hr': '33',
#    'PM10': '17',
#    'PM2.5': '5',
#    'NO2': '2',
#    'NOx': '2.4',
#    'NO': '0.4',
#    'WindSpeed': '3.7',
#    'WindDirec': '190',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '15',
#    'PM10_AVG': '29',
#    'SO2_AVG': '1',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'SiteId': '77',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '馬公',
#    'County': '澎湖縣',
#    'AQI': '41',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.7',
#    'CO': '0.16',
#    'CO_8hr': '0.1',
#    'O3': '42.9',
#    'O3_8hr': '44',
#    'PM10': '18',
#    'PM2.5': '9',
#    'NO2': '2',
#    'NOx': '2.3',
#    'NO': '0.2',
#    'WindSpeed': '1.7',
#    'WindDirec': '283',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '',
#    'PM10_AVG': '21',
#    'SO2_AVG': '0',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'SiteId': '78',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '關山',
#    'County': '臺東縣',
#    'AQI': '8',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.1',
#    'CO': '-',
#    'CO_8hr': '-',
#    'O3': '17.2',
#    'O3_8hr': '9',
#    'PM10': '6',
#    'PM2.5': '0',
#    'NO2': '1.6',
#    'NOx': '2.5',
#    'NO': '0.8',
#    'WindSpeed': '1.8',
#    'WindDirec': '188',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '0',
#    'PM10_AVG': '8',
#    'SO2_AVG': '1',
#    'Longitude': '121.161933',
#    'Latitude': '23.045083',
#    'SiteId': '80',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '麥寮',
#    'County': '雲林縣',
#    'AQI': '61',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.3',
#    'CO': '0.17',
#    'CO_8hr': '0.2',
#    'O3': '51.3',
#    'O3_8hr': '35',
#    'PM10': '17',
#    'PM2.5': '11',
#    'NO2': '7.5',
#    'NOx': '9.6',
#    'NO': '2',
#    'WindSpeed': '1.8',
#    'WindDirec': '263',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '19',
#    'PM10_AVG': '32',
#    'SO2_AVG': '2',
#    'Longitude': '120.251825',
#    'Latitude': '23.753506',
#    'SiteId': '83',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '富貴角',
#    'County': '新北市',
#    'AQI': '37',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.5',
#    'CO': '0.12',
#    'CO_8hr': '0.1',
#    'O3': '53.4',
#    'O3_8hr': '40',
#    'PM10': '22',
#    'PM2.5': '8',
#    'NO2': '1.1',
#    'NOx': '1.3',
#    'NO': '0.1',
#    'WindSpeed': '2.5',
#    'WindDirec': '262',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '9',
#    'PM10_AVG': '20',
#    'SO2_AVG': '0',
#    'Longitude': '121.54738',
#    'Latitude': '25.29228',
#    'SiteId': '84',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '大城',
#    'County': '彰化縣',
#    'AQI': '49',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.8',
#    'CO': '0.09',
#    'CO_8hr': '0.1',
#    'O3': '52.6',
#    'O3_8hr': '36',
#    'PM10': '19',
#    'PM2.5': '8',
#    'NO2': '1.4',
#    'NOx': '2.8',
#    'NO': '1.4',
#    'WindSpeed': '3.2',
#    'WindDirec': '304',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '15',
#    'PM10_AVG': '25',
#    'SO2_AVG': '1',
#    'Longitude': '120.26964167',
#    'Latitude': '23.85493056',
#    'SiteId': '85',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '高雄(湖內)',
#    'County': '高雄市',
#    'AQI': '45',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.2',
#    'CO': '0.17',
#    'CO_8hr': '0.2',
#    'O3': '45.1',
#    'O3_8hr': '33',
#    'PM10': '17',
#    'PM2.5': '10',
#    'NO2': '4.3',
#    'NOx': '4.8',
#    'NO': '0.5',
#    'WindSpeed': '2.6',
#    'WindDirec': '72',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '13',
#    'PM10_AVG': '24',
#    'SO2_AVG': '1',
#    'Longitude': '120.24535',
#    'Latitude': '22.87985556',
#    'SiteId': '202',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '臺南(麻豆)',
#    'County': '臺南市',
#    'AQI': '',
#    'Pollutant': '',
#    'Status': '',
#    'SO2': '',
#    'CO': '',
#    'CO_8hr': '',
#    'O3': '',
#    'O3_8hr': '',
#    'PM10': '',
#    'PM2.5': '',
#    'NO2': '',
#    'NOx': '',
#    'NO': '',
#    'WindSpeed': '',
#    'WindDirec': '',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '',
#    'PM10_AVG': '',
#    'SO2_AVG': '',
#    'Longitude': '120.24583056',
#    'Latitude': '23.17904722',
#    'SiteId': '203',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '屏東(琉球)',
#    'County': '屏東縣',
#    'AQI': '81',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.2',
#    'CO': '0.3',
#    'CO_8hr': '0.3',
#    'O3': '70.6',
#    'O3_8hr': '48',
#    'PM10': '34',
#    'PM2.5': '23',
#    'NO2': '3.7',
#    'NOx': '4.6',
#    'NO': '0.8',
#    'WindSpeed': '2.7',
#    'WindDirec': '312',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '27',
#    'PM10_AVG': '42',
#    'SO2_AVG': '1',
#    'Longitude': '120.37722',
#    'Latitude': '22.35222',
#    'SiteId': '204',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '新北(樹林)',
#    'County': '新北市',
#    'AQI': '65',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.7',
#    'CO': '0.26',
#    'CO_8hr': '0.3',
#    'O3': '56.9',
#    'O3_8hr': '32',
#    'PM10': '21',
#    'PM2.5': '16',
#    'NO2': '5.7',
#    'NOx': '6.3',
#    'NO': '0.5',
#    'WindSpeed': '0.3',
#    'WindDirec': '18',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '21',
#    'PM10_AVG': '30',
#    'SO2_AVG': '0',
#    'Longitude': '121.38352778',
#    'Latitude': '24.94902778',
#    'SiteId': '311',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '臺南(學甲)',
#    'County': '臺南市',
#    'AQI': '45',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.2',
#    'CO': '0.14',
#    'CO_8hr': '0.1',
#    'O3': '35.4',
#    'O3_8hr': '28',
#    'PM10': '17',
#    'PM2.5': '8',
#    'NO2': '3.9',
#    'NOx': '7.2',
#    'NO': '3.3',
#    'WindSpeed': '2.3',
#    'WindDirec': '324',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '14',
#    'PM10_AVG': '28',
#    'SO2_AVG': '0',
#    'Longitude': '120.18339722',
#    'Latitude': '23.23688056',
#    'SiteId': '312',
#    'ImportDate': '2021-09-20 13:22:01.227000'},
#   {'SiteName': '屏東(建興)',
#    'County': '屏東縣',
#    'AQI': '39',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '2.4',
#    'CO': '0.31',
#    'CO_8hr': '0.2',
#    'O3': '99.1',
#    'O3_8hr': '42',
#    'PM10': '46',
#    'PM2.5': '',
#    'NO2': '5.8',
#    'NOx': '6',
#    'NO': '0.2',
#    'WindSpeed': '1.3',
#    'WindDirec': '293',
#    'PublishTime': '2021/09/20 13:00:00',
#    'PM2.5_AVG': '',
#    'PM10_AVG': '27',
#    'SO2_AVG': '0',
#    'Longitude': '121.00379167',
#    'Latitude': '22.650525',
#    'SiteId': '313',
#    'ImportDate': '2021-09-20 13:22:01.227000'}],
#  'limit': 1000,
#  'offset': 0,
#  '_links': {'start': '/api/v1/aqx_p_432?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&format=json',
#   'next': '/api/v1/aqx_p_432?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&offset=1000&format=json'},
#  'distribution': [{'qcLevel': '/result/records'}],
#  'total': 84}

# %%
data.keys()
# Out:
# dict_keys(['sort', 'include_total', 'resource_id', 'fields', '__extras', 'records_format', 'records', 'limit', 'offset', '_links', 'distribution', 'total'])

# %%
len(data['records'])
# Out:
# 84

# %%
# 請填入你的程式

# %% [markdown]
# ### MariaDB的操作
#
# - 他們的爸爸是同一個，只是一個是大女兒，一個是二女兒，操作方式大同小異
